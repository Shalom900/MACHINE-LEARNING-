# %%
# Importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv('housing.csv')

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2         496         177         7.2574              352100        NEAR BAY
# 3         558         219         5.6431              341300        NEAR BAY
# 4         565         259         3.8462              342200        NEAR BAY

# %%
df.shape
# Out:
# (20640, 10)

# %%
#Drop rows containing null values

# %%
df = df.dropna(axis=0).reset_index(drop = True)

# %%
X = df.drop(['population', 'ocean_proximity'], axis=1)

y = df['population']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
X_train.shape, X_test.shape
# Out:
# ((14303, 8), (6130, 8))

# %%
X_train.head(), X_test.head()
# Out:
# (       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
#  19375    -120.96     37.61                  23         3497           887.0
#  7212     -118.22     33.98                  34         2225           753.0
#  17452    -121.94     37.28                  27         2859           464.0
#  17352    -121.91     37.34                  35         2189           607.0
#  5118     -118.28     33.95                  41          835           208.0
#
#         households  median_income  median_house_value
#  19375         816         1.9444               93400
#  7212          736         1.6685              128800
#  17452         430         5.0822              327500
#  17352         562         2.8042              240900
#  5118          192         1.4103               86200  ,
#         longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
#  14278    -117.24     32.79                  20          961           278.0
#  16224    -121.29     38.01                   2         6403          1116.0
#  7646     -118.14     33.92                  31         3731           853.0
#  1402     -122.07     37.94                  30         1260           276.0
#  1328     -121.89     37.99                   4         2171           597.0
#
#         households  median_income  median_house_value
#  14278         254         3.1838              245800
#  16224         957         4.4871              137900
#  7646          801         3.2237              218200
#  1402          221         2.8920              220800
#  1328          461         4.1016              170500  )

# %%
#Feature Engineering

# %%
X_train.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age      int64
# total_rooms             int64
# total_bedrooms        float64
# households              int64
# median_income         float64
# median_house_value      int64
# dtype: object

# %%
X_train.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 19375    -120.96     37.61                  23         3497           887.0
# 7212     -118.22     33.98                  34         2225           753.0
# 17452    -121.94     37.28                  27         2859           464.0
# 17352    -121.91     37.34                  35         2189           607.0
# 5118     -118.28     33.95                  41          835           208.0
#
#        households  median_income  median_house_value
# 19375         816         1.9444               93400
# 7212          736         1.6685              128800
# 17452         430         5.0822              327500
# 17352         562         2.8042              240900
# 5118          192         1.4103               86200

# %%
y_train.dtypes
# Out:
# dtype('int64')

# %%
y_train.head()
# Out:
# 19375    2467
# 7212     2980
# 17452    1144
# 17352    1193
# 5118      707
# Name: population, dtype: int64

# %%
# Training the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Making predictions on the test set
y_pred = model.predict(X_test)

# Extracting the coefficients
coefficients = pd.DataFrame(model.coef_, X.columns, columns=['Coefficient'])
print(coefficients)
# Out:
#                     Coefficient
# longitude            -63.596996
# latitude             -93.050184
# housing_median_age     0.660713
# total_rooms            0.185055
# total_bedrooms        -1.455913
# households             3.338840
# median_income          2.879047
# median_house_value    -0.001506
